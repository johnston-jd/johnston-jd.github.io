# %%
from animal_shelter import AnimalShelter
from bson.objectid import ObjectId

#Instantiates AnimalShelter class and the credenitals
animals = AnimalShelter('aacuser', 'JandO1427')

#create animal for a new insert
print (animals.create ( {
    'age_upon_outcome' : '5 years',
    'animal_id' : 'TestId',
    'animal_type' : 'Dog',
    'breed' : 'Irish Wolfhound',
    'color' : 'Grey',
    'date_of_birth' : '2019-03-14',
    'datetime' : '2024-06-09 12:30:00',
    'monthyear' : '2024-06-09 12:30:00',
    'name' : 'Clark',
    'outcome_subtype' : '',
    'outcome_type' : 'Adopted',
    'sex_upon_outcome' : 'Neutered Male',
    'location_lat' : 30.4792884863566,
    'location_long' : -97.4088531587999,
    'age_upon_outcome_in_weeks' : 261.8181
    
}))
#search for newly created animal
animalSearch = animals.read({'name' : 'Clark'})
for animal in animalSearch:
    print(animal)
    
#update animal
animalUpdate = animals.update({'name' : 'Clark'}, {'animal_id' : 'Z4723A'})
for animals in animalUpdate:
    print(animalUpdate)
    
#Delete animal
animalDelete = animals.delete({'name' : 'Clark'})
print(animalDelete)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Input In [1], in <cell line: 8>()
#       5 animals = AnimalShelter('aacuser', 'JandO1427')
#       7 #create animal for a new insert
# ----> 8 print (animals.create ( {
#       9     'age_upon_outcome' : '5 years',
#      10     'animal_id' : 'TestId',
#      11     'animal_type' : 'Dog',
#      12     'breed' : 'Irish Wolfhound',
#      13     'color' : 'Grey',
#      14     'date_of_birth' : '2019-03-14',
#      15     'datetime' : '2024-06-09 12:30:00',
#      16     'monthyear' : '2024-06-09 12:30:00',
#      17     'name' : 'Clark',
#      18     'outcome_subtype' : '',
#      19     'outcome_type' : 'Adopted',
#      20     'sex_upon_outcome' : 'Neutered Male',
#      21     'location_lat' : 30.4792884863566,
#      22     'location_long' : -97.4088531587999,
#      23     'age_upon_outcome_in_weeks' : 261.8181
#      24
# ...
